# %% [markdown]
# # 1 Notebook Setup

# %%
import os
import sys
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)
import pandas as pd
import pickle

# %%
# Add src folder to environmental path
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), os.pardir, 'src/')))

# %% [markdown]
# # 2 Loading Baseline Model & Extracted Event, Parse Event

# %%
# To keep root folder intact, load inputs from temporary directory 'examples/input/'
in_dir = 'input/'
isExist = os.path.exists(in_dir)
if not isExist:
    os.makedirs(in_dir)

# support your input baseline model here
model_file = 'BooleanTcell.xlsx'
baseline = in_dir + model_file

# %%
from runAccordion import get_model

# Load baseline model file into two dictionaries
# we highlight the key information of the baseline model
model_dict, regulators = get_model(baseline)
df_model = pd.read_excel(baseline, index_col=0)
df_model[['Element name','Element IDs','Positive regulators','Negative regulators','Levels','Initial 0']]
# Out:
#    Element name    Element IDs Positive regulators Negative regulators  \
# #
# 1           AKT         P31749       (PDK1,MTORC2)             AKT_OFF
# 2       AKT_OFF         P31749                 NaN                 NaN
# 3           AP1  P05412,P01100        (FOS_DD,JUN)                 NaN
# 4            CA            NaN                 TCR                 NaN
# 5         CD122         P14784                 NaN                 NaN
# ..          ...            ...                 ...                 ...
# 58     TCR_HIGH  P01850,P01848                 NaN                 NaN
# 59      TCR_LOW  P01850,P01848                 NaN                 NaN
# 60      TGFBETA         P01137                 NaN                 NaN
# 61          TSC  Q92574,P49815                 NaN                 AKT
# 62        FOXO1            NaN                 NaN                 NaN
#
#     Levels  Initial 0
# #
# 1        2          0
# 2        2          0
# 3        2          0
# 4        2          0
# 5        2          1
# ..     ...        ...
# 58       2          0
# 59       2          0
# 60       2          0
# 61       2          1
# 62       2          1
#
# [62 rows x 6 columns]

# %%
# 'model_dict' is a dictionary that holds critical information of each baseline model element
# 'regulators' is a dict that contains baseline model elements and corresponding regulator elements
# model_dict
regulators
# Out:
# {'AKT': {'AKT_OFF', 'MTORC2', 'PDK1'},
#  'AKT_OFF': set(),
#  'AP1': {'FOS_DD', 'JUN'},
#  'CA': {'TCR'},
#  'CD122': set(),
#  'CD132': set(),
#  'CD25': {'AP1', 'FOXP3', 'NFAT', 'NFKAPPAB', 'STAT5'},
#  'CD28': set(),
#  'ERK': {'MEK2'},
#  'FOS': {'ERK'},
#  'FOS_D': {'FOS'},
#  'FOS_DD': {'FOS_D'},
#  'FOS_DDD': set(),
#  'FOXP3': {'MTOR_DD', 'NFAT', 'SMAD3', 'STAT5'},
#  'IL2': {'AP1', 'FOXP3', 'IL2', 'NFAT', 'NFKAPPAB'},
#  'IL2_EX': {'IL2', 'IL2_EX'},
#  'IL2R': {'CD122', 'CD132', 'CD25'},
#  'JAK3': {'IL2R', 'IL2_EX'},
#  'JNK': {'MKK7'},
#  'JUN': {'JNK'},
#  'MEK2': {'RAF'},
#  'MKK7': {'TAK1'},
#  'MTOR': {'MTORC1_D', 'MTORC2_D'},
#  'MTOR_D': {'MTOR'},
#  'MTOR_DD': {'MTOR_D'},
#  'MTOR_DDD': set(),
#  'MTOR_DDDD': set(),
#  'MTORC1': {'MTORC1_OFF', 'RHEB'},
#  'MTORC1_D': {'MTORC1'},
#  'MTORC1_OFF': set(),
#  'MTORC2': {'PI3K_HIGH', 'PI3K_LOW', 'S6K1'},
#  'MTORC2_D': {'MTORC2'},
#  'MTORC2_DD': set(),
#  'NFAT': {'CA', 'NFAT_OFF'},
#  'NFAT_OFF': set(),
#  'NFKAPPAB': {'AKT', 'PKCTHETA'},
#  'PDK1': {'PIP3'},
#  'PI3K': {'PI3K_HIGH', 'PI3K_LOW'},
#  'PI3K_HIGH': {'CD28', 'IL2R', 'IL2_EX', 'PI3K_HIGH', 'TCR_HIGH'},
#  'PI3K_LOW': {'CD28', 'IL2R', 'IL2_EX', 'PI3K_LOW', 'TCR_LOW'},
#  'PIP3': {'PIP3_HIGH', 'PIP3_LOW'},
#  'PIP3_HIGH': {'PI3K_HIGH', 'PTEN'},
#  'PIP3_LOW': {'PI3K_LOW', 'PTEN'},
#  'PKCTHETA': {'CD28', 'MTORC2', 'TCR_HIGH', 'TCR_LOW'},
#  'PS6': {'S6K1'},
#  'PTEN': {'FOXP3', 'PTEN', 'TCR_HIGH'},
#  'RAF': {'RAS'},
#  'RAS': {'CD28', 'IL2R', 'IL2_EX', 'RAS', 'TCR'},
#  'RHEB': {'TSC'},
#  'S6K1': {'MTORC1'},
#  'SMAD3': {'TGFBETA'},
#  'STAT5': {'JAK3'},
#  'STAT5_D': {'STAT5'},
#  'STAT5_DD': set(),
#  'STAT5_DDD': set(),
#  'TAK1': {'PKCTHETA'},
#  'TCR': {'TCR_HIGH', 'TCR_LOW'},
#  'TCR_HIGH': set(),
#  'TCR_LOW': set(),
#  'TGFBETA': set(),
#  'TSC': {'AKT'},
#  'FOXO1': set()}

# %%
# support your extracted event information here, it is from machine reading
reading_file = 'MachineReadingOutput.csv'
reading = 'input/' + reading_file

# %%
# we highlight the key information of each event
df_ro = pd.read_csv(reading)
df_ro[['regulator_name', 'ID1', 'regulated_name','ID2', 'interaction', 'PaperID']]
# Out:
#     regulator_name     ID1 regulated_name        ID2 interaction     PaperID
# 0              AKT  P31749            CD4     P01730   decreases  PMC2275380
# 1              AKT  P31749           CTRL     P40313   decreases  PMC2275380
# 2          TGFBETA  P01137            AKT     P31749   increases  PMC2275380
# 3            Foxp3  Q9BZS1          Ctla4     P16410   increases  PMC2275380
# 4            Foxp3  Q9BZS1          Gpr83     Q9NYM4   increases  PMC2275380
# ..             ...     ...            ...        ...         ...         ...
# 112         MTORC2  Q6R328         MTORC2     Q6R327   increases  PMC4418530
# 113           CD28  P10747         MTORC2     Q6R328   increases  PMC4418530
# 114         IL2_EX  P60568         MTORC2     Q6R329   increases  PMC4418530
# 115          IL2_R  P01589         MTORC2     Q6R330   increases  PMC4418530
# 116           PI3K  P42336           PIP3  HMDB10147   increases  PMC4418530
#
# [117 rows x 6 columns]

# %%
# parse the reading output file (extracted events) into a set() object
# each component in the set has format: (regulator element, regulated element, type of interaction (+/-))
from runAccordion import parseExtension
exttt=parseExtension(model_dict, reading)
exttt
# Out:
# {('AKT', 'CD4_ext', '-'),
#  ('AKT', 'CTRL_ext', '-'),
#  ('AKT', 'FOXO1', '-'),
#  ('AKT', 'FoxO3_ext', '-'),
#  ('AKT', 'Itk_ext', '-'),
#  ('AKT', 'MAGI1_ext', '-'),
#  ('AKT', 'MEK1_ext', '-'),
#  ('AKT', 'MTORC2', '-'),
#  ('AKT', 'TBK1_ext', '+'),
#  ('BAM32_ext', 'PAK1_ext', '+'),
#  ('BIM_ext', 'PAK1_ext', '+'),
#  ('Bcl2_ext', 'CD3_ext', '+'),
#  ('Bcl2l11_ext', 'CD4_ext', '+'),
#  ('CD25', 'MTORC2', '+'),
#  ('CD28', 'MTORC2', '+'),
#  ('CD4_ext', 'IL17A_ext', '-'),
#  ('CD5_ext', 'CK2_ext', '+'),
#  ('CD5_ext', 'P38_ext', '+'),
#  ('CHK1_ext', 'AKT', '+'),
#  ('CK2_ext', 'AKT', '+'),
#  ('CK2_ext', 'CD4_ext', '+'),
#  ('CK2_ext', 'CDC37_ext', '+'),
#  ('CK2_ext', 'PTEN', '-'),
#  ('CTLA4_ext', 'AKT', '-'),
#  ('ERK', 'CK2_ext', '+'),
#  ('ERK', 'PAK1_ext', '+'),
#  ('ERK', 'S5B_ext', '+'),
#  ('FASL_ext', 'FAS_ext', '+'),
#  ('FOXO1', 'Foxo3a_ext', '-'),
#  ('FOXO1', 'PTEN', '+'),
#  ('FOXO3_ext', 'FOXO3_ext', '+'),
#  ('FOXP3', 'Ctla4_ext', '+'),
#  ('FOXP3', 'Gpr83_ext', '+'),
#  ('FOXP3', 'Itk_ext', '+'),
#  ('HIF1alpha_ext', 'IL17A_ext', '-'),
#  ('IFNgamma_ext', 'AKT', '+'),
#  ('IL2', 'Itk_ext', '+'),
#  ('IL2', 'MTORC2', '+'),
#  ('IQGAP1_ext', 'MEK2', '-'),
#  ('Itk_ext', 'CD4_ext', '+'),
#  ('Itk_ext', 'CD4_ext', '-'),
#  ('Itk_ext', 'Myc_ext', '-'),
#  ('Itk_ext', 'Th17_ext', '+'),
#  ('MEK1_ext', 'AKT', '-'),
#  ('MEK1_ext', 'PTEN', '+'),
#  ('MEK2', 'PTEN', '+'),
#  ('MTOR', 'AKT', '+'),
#  ('MTOR', 'PAK1_ext', '+'),
#  ('MTOR', 'Pak1_ext', '-'),
#  ('MTOR', 'TBK1_ext', '+'),
#  ('MTORC2', 'AKT', '+'),
#  ('MTORC2', 'MTORC2', '+'),
#  ('NEDD4_ext', 'PTEN', '-'),
#  ('P38_ext', 'CD5_ext', '+'),
#  ('P53_ext', 'PTEN', '-'),
#  ('PD1_ext', 'AKT', '-'),
#  ('PDK1', 'AKT', '+'),
#  ('PDL1_ext', 'CD8_ext', '-'),
#  ('PDL1_ext', 'Treg_ext', '-'),
#  ('PDL1_ext', 'gp120_ext', '+'),
#  ('PI3K', 'AKT', '+'),
#  ('PI3K', 'AKT', '-'),
#  ('PI3K', 'PAK1_ext', '-'),
#  ('PI3K', 'PIP3', '+'),
#  ('PI3K', 'PTEN', '+'),
#  ('PI3K', 'PTEN', '-'),
#  ('PIP3', 'AKT', '+'),
#  ('PTEN', 'AKT', '+'),
#  ('PTEN', 'AKT', '-'),
#  ('PTEN', 'CD8_ext', '+'),
#  ('PTEN', 'HSC_ext', '+'),
#  ('PTEN', 'Itk_ext', '-'),
#  ('PTEN', 'PIP3', '-'),
#  ('RAS', 'PTEN', '-'),
#  ('SHIP1_ext', 'AKT', '-'),
#  ('SHIP_ext', 'PI3K', '+'),
#  ('SP_ext', 'CD69_ext', '+'),
#  ('TBK1_ext', 'AKT', '+'),
#  ('TBK1_ext', 'AKT', '-'),
#  ('TBK1_ext', 'CD4_ext', '+'),
#  ('TBK1_ext', 'CD4_ext', '-'),
#  ('TBK1_ext', 'FOXO1', '+'),
#  ('TCR', 'AKT', '-'),
#  ('TCR', 'CD25', '+'),
#  ('TCR', 'CD4_ext', '-'),
#  ('TCR', 'CK2_ext', '+'),
#  ('TCR', 'Itk_ext', '+'),
#  ('TCR', 'MEK1_ext', '+'),
#  ('TCR', 'MTORC2', '+'),
#  ('TCR', 'NEDD4_ext', '+'),
#  ('TCR', 'PIP3', '+'),
#  ('TCR', 'PTEN', '-'),
#  ('TGFBETA', 'AKT', '+'),
#  ('TIL_ext', 'AKT', '-'),
#  ('siPAK1_ext', 'PAK1_ext', '-')}

# %% [markdown]
# # 3 Clustering, Generate Extension Candidates, Merging

# %%
# To keep root folder intact, generate output in temporary directory 'examples/output'
out_dir = 'output/'

isExist = os.path.exists(out_dir)
if not isExist:
    os.makedirs()

# %%
# Build non-python dependencies for the usage of function runMarkovCluster()
import subprocess
command = "cd ../dependencies/mcl-14-137"
command += " && ./configure && make && make install && make clean && make distclean"
process = subprocess.Popen(command, shell=True)
process.wait()
# Out:
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... autofoo/install-sh -c -d
# checking for gawk... no
# checking for mawk... no
# checking for nawk... no
# checking for awk... awk
# checking whether make sets $(MAKE)... yes
# checking whether to enable maintainer-specific portions of Makefiles... no
# checking for style of include used by make... GNU
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking dependency style of gcc... gcc3
# checking  _____ weak test for C void* <=> unsigned int conversion... failed
#   /\  custom check: num <-> void* failed: do not use --abc options.
#  /\/\ Consider contacting the author (http://micans.org/stijn/contact.html
#  \/\/
#   \/  Please include the file config.log.
# checking for gawk... (cached) awk
# checking for gcc... (cached) gcc
# checking whether we are using the GNU C compiler... (cached) yes
# checking whether gcc accepts -g... (cached) yes
# checking for gcc option to accept ISO C89... (cached) none needed
# checking dependency style of gcc... (cached) gcc3
# checking whether ln -s works... yes
# checking for ranlib... ranlib
# checking for main in -lm... yes
# checking how to run the C preprocessor... gcc -E
# checking for grep that handles long lines and -e... /usr/bin/grep
# checking for egrep... /usr/bin/grep -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking float.h usability... yes
# checking float.h presence... yes
# checking for float.h... yes
# checking limits.h usability... yes
# checking limits.h presence... yes
# checking for limits.h... yes
# checking malloc.h usability... no
# checking malloc.h presence... no
# checking for malloc.h... no
# checking for stdlib.h... (cached) yes
# checking for string.h... (cached) yes
# checking for unistd.h... (cached) yes
# checking for an ANSI C-conforming const... yes
# checking for size_t... yes
# checking build system type... i686-apple-darwin22.2.0
# checking host system type... i686-apple-darwin22.2.0
# checking for the pthreads library -lpthreads... no
# checking whether pthreads work without any flags... yes
# checking for joinable pthread attribute... PTHREAD_CREATE_JOINABLE
# checking if more special flags are required for pthreads... -D_THREAD_SAFE
# checking for cc_r... gcc
# checking for stdlib.h... (cached) yes
# checking for GNU libc compatible malloc... yes
# checking for working memcmp... yes
# checking for vprintf... yes
# checking for _doprnt... no
# checking for floor... yes
# checking for memset... yes
# checking for pow... yes
# checking for rint... yes
# checking for sqrt... yes
# checking for strchr... yes
# checking for strpbrk... yes
# checking for strstr... yes
# checking for va_copy() function... yes
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating include/Makefile
# config.status: creating doc/Makefile
# config.status: creating testing/Makefile
# config.status: creating testing/stream/Makefile
# config.status: creating testing/blast/Makefile
# config.status: creating testing/setops/Makefile
# config.status: creating graphs/Makefile
# config.status: creating img/Makefile
# config.status: creating scripts/Makefile
# config.status: creating util/Makefile
# config.status: creating src/Makefile
# config.status: creating src/clew/Makefile
# config.status: creating src/mcl/Makefile
# config.status: creating src/gryphon/Makefile
# config.status: creating src/impala/Makefile
# config.status: creating src/shcl/Makefile
# config.status: creating src/shmcl/Makefile
# config.status: creating src/shmx/Makefile
# config.status: creating src/shmcxquery/Makefile
# config.status: creating src/shmcx/Makefile
# config.status: creating src/alien/Makefile
# config.status: creating src/alien/oxygen/Makefile
# config.status: creating src/alien/oxygen/doc/Makefile
# config.status: creating src/alien/oxygen/src/Makefile
# config.status: creating config.h
# config.status: executing depfiles commands
# /Library/Developer/CommandLineTools/usr/bin/make  all-recursive
# Making all in .
# make[2]: Nothing to be done for `all-am'.
# Making all in util
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT alloc.o -MD -MP -MF .deps/alloc.Tpo -c -o alloc.o alloc.c
# mv -f .deps/alloc.Tpo .deps/alloc.Po
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT array.o -MD -MP -MF .deps/array.Tpo -c -o array.o array.c
# mv -f .deps/array.Tpo .deps/array.Po
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT rand.o -MD -MP -MF .deps/rand.Tpo -c -o rand.o rand.c
# mv -f .deps/rand.Tpo .deps/rand.Po
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT equate.o -MD -MP -MF .deps/equate.Tpo -c -o equate.o equate.c
# mv -f .deps/equate.Tpo .deps/equate.Po
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT opt.o -MD -MP -MF .deps/opt.Tpo -c -o opt.o opt.c
# opt.c:870:28: warning: self-comparison always evaluates to false [-Wtautological-compare]
#       ;  if (hk->n_at_most > hk->n_at_most)
#                            ^
# 1 warning generated.
# mv -f .deps/opt.Tpo .deps/opt.Po
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT io.o -MD -MP -MF .deps/io.Tpo -c -o io.o io.c
# mv -f .deps/io.Tpo .deps/io.Po
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT err.o -MD -MP -MF .deps/err.Tpo -c -o err.o err.c
# mv -f .deps/err.Tpo .deps/err.Po
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT hash.o -MD -MP -MF .deps/hash.Tpo -c -o hash.o hash.c
# mv -f .deps/hash.Tpo .deps/hash.Po
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT heap.o -MD -MP -MF .deps/heap.Tpo -c -o heap.o heap.c
# mv -f .deps/heap.Tpo .deps/heap.Po
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT let.o -MD -MP -MF .deps/let.Tpo -c -o let.o let.c
# mv -f .deps/let.Tpo .deps/let.Po
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT list.o -MD -MP -MF .deps/list.Tpo -c -o list.o list.c
# mv -f .deps/list.Tpo .deps/list.Po
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT gralloc.o -MD -MP -MF .deps/gralloc.Tpo -c -o gralloc.o gralloc.c
# mv -f .deps/gralloc.Tpo .deps/gralloc.Po
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT tok.o -MD -MP -MF .deps/tok.Tpo -c -o tok.o tok.c
# mv -f .deps/tok.Tpo .deps/tok.Po
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT ting.o -MD -MP -MF .deps/ting.Tpo -c -o ting.o ting.c
# mv -f .deps/ting.Tpo .deps/ting.Po
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT ding.o -MD -MP -MF .deps/ding.Tpo -c -o ding.o ding.c
# mv -f .deps/ding.Tpo .deps/ding.Po
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT tr.o -MD -MP -MF .deps/tr.Tpo -c -o tr.o tr.c
# mv -f .deps/tr.Tpo .deps/tr.Po
# gcc -DHAVE_CONFIG_H -I. -I.. -I..    -g -O2 -D_THREAD_SAFE  -MT types.o -MD -MP -MF .deps/types.Tpo -c -o types.o types.c
# mv -f .deps/types.Tpo .deps/types.Po
# rm -f libutil.a
# ar cru libutil.a alloc.o array.o rand.o equate.o opt.o io.o err.o hash.o heap.o let.o list.o gralloc.o tok.o ting.o ding.o tr.o types.o
# ranlib libutil.a
# Making all in img
# make[2]: Nothing to be done for `all'.
# Making all in graphs
# make[2]: Nothing to be done for `all'.
# Making all in doc
# make[2]: Nothing to be done for `all'.
# Making all in src
# Making all in .
# make[3]: Nothing to be done for `all-am'.
# Making all in clew
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT scan.o -MD -MP -MF .deps/scan.Tpo -c -o scan.o scan.c
# mv -f .deps/scan.Tpo .deps/scan.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT claw.o -MD -MP -MF .deps/claw.Tpo -c -o claw.o claw.c
# mv -f .deps/claw.Tpo .deps/claw.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clm.o -MD -MP -MF .deps/clm.Tpo -c -o clm.o clm.c
# mv -f .deps/clm.Tpo .deps/clm.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT cat.o -MD -MP -MF .deps/cat.Tpo -c -o cat.o cat.c
# mv -f .deps/cat.Tpo .deps/cat.Po
# rm -f libclew.a
# ar cru libclew.a scan.o claw.o clm.o cat.o
# ranlib libclew.a
# Making all in mcl
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT shadow.o -MD -MP -MF .deps/shadow.Tpo -c -o shadow.o shadow.c
# mv -f .deps/shadow.Tpo .deps/shadow.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT inflate.o -MD -MP -MF .deps/inflate.Tpo -c -o inflate.o inflate.c
# mv -f .deps/inflate.Tpo .deps/inflate.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT alg.o -MD -MP -MF .deps/alg.Tpo -c -o alg.o alg.c
# mv -f .deps/alg.Tpo .deps/alg.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT expand.o -MD -MP -MF .deps/expand.Tpo -c -o expand.o expand.c
# mv -f .deps/expand.Tpo .deps/expand.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT dpsd.o -MD -MP -MF .deps/dpsd.Tpo -c -o dpsd.o dpsd.c
# mv -f .deps/dpsd.Tpo .deps/dpsd.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT interpret.o -MD -MP -MF .deps/interpret.Tpo -c -o interpret.o interpret.c
# mv -f .deps/interpret.Tpo .deps/interpret.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT proc.o -MD -MP -MF .deps/proc.Tpo -c -o proc.o proc.c
# mv -f .deps/proc.Tpo .deps/proc.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT procinit.o -MD -MP -MF .deps/procinit.Tpo -c -o procinit.o procinit.c
# mv -f .deps/procinit.Tpo .deps/procinit.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT transform.o -MD -MP -MF .deps/transform.Tpo -c -o transform.o transform.c
# mv -f .deps/transform.Tpo .deps/transform.Po
# rm -f libmcl.a
# ar cru libmcl.a shadow.o inflate.o alg.o expand.o dpsd.o interpret.o proc.o procinit.o transform.o
# ranlib libmcl.a
# Making all in gryphon
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT path.o -MD -MP -MF .deps/path.Tpo -c -o path.o path.c
# mv -f .deps/path.Tpo .deps/path.Po
# rm -f libgryphon.a
# ar cru libgryphon.a path.o
# ranlib libgryphon.a
# Making all in impala
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT compose.o -MD -MP -MF .deps/compose.Tpo -c -o compose.o compose.c
# mv -f .deps/compose.Tpo .deps/compose.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT tab.o -MD -MP -MF .deps/tab.Tpo -c -o tab.o tab.c
# mv -f .deps/tab.Tpo .deps/tab.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT pval.o -MD -MP -MF .deps/pval.Tpo -c -o pval.o pval.c
# mv -f .deps/pval.Tpo .deps/pval.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT iface.o -MD -MP -MF .deps/iface.Tpo -c -o iface.o iface.c
# mv -f .deps/iface.Tpo .deps/iface.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT io.o -MD -MP -MF .deps/io.Tpo -c -o io.o io.c
# mv -f .deps/io.Tpo .deps/io.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT ivp.o -MD -MP -MF .deps/ivp.Tpo -c -o ivp.o ivp.c
# mv -f .deps/ivp.Tpo .deps/ivp.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT edge.o -MD -MP -MF .deps/edge.Tpo -c -o edge.o edge.c
# mv -f .deps/edge.Tpo .deps/edge.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT matrix.o -MD -MP -MF .deps/matrix.Tpo -c -o matrix.o matrix.c
# mv -f .deps/matrix.Tpo .deps/matrix.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT vector.o -MD -MP -MF .deps/vector.Tpo -c -o vector.o vector.c
# mv -f .deps/vector.Tpo .deps/vector.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT version.o -MD -MP -MF .deps/version.Tpo -c -o version.o version.c
# mv -f .deps/version.Tpo .deps/version.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT app.o -MD -MP -MF .deps/app.Tpo -c -o app.o app.c
# mv -f .deps/app.Tpo .deps/app.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT stream.o -MD -MP -MF .deps/stream.Tpo -c -o stream.o stream.c
# mv -f .deps/stream.Tpo .deps/stream.Po
# rm -f libimpala.a
# ar cru libimpala.a compose.o tab.o pval.o iface.o io.o ivp.o edge.o matrix.o vector.o version.o app.o stream.o
# ranlib libimpala.a
# Making all in shcl
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clmformat.o -MD -MP -MF .deps/clmformat.Tpo -c -o clmformat.o clmformat.c
# mv -f .deps/clmformat.Tpo .deps/clmformat.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT report.o -MD -MP -MF .deps/report.Tpo -c -o report.o report.c
# mv -f .deps/report.Tpo .deps/report.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o clmformat clmformat.o report.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clm.o -MD -MP -MF .deps/clm.Tpo -c -o clm.o clm.c
# mv -f .deps/clm.Tpo .deps/clm.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clminfo2.o -MD -MP -MF .deps/clminfo2.Tpo -c -o clminfo2.o clminfo2.c
# mv -f .deps/clminfo2.Tpo .deps/clminfo2.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clminfo.o -MD -MP -MF .deps/clminfo.Tpo -c -o clminfo.o clminfo.c
# mv -f .deps/clminfo.Tpo .deps/clminfo.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clmimac.o -MD -MP -MF .deps/clmimac.Tpo -c -o clmimac.o clmimac.c
# mv -f .deps/clmimac.Tpo .deps/clmimac.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clmadjust.o -MD -MP -MF .deps/clmadjust.Tpo -c -o clmadjust.o clmadjust.c
# mv -f .deps/clmadjust.Tpo .deps/clmadjust.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clmresidue.o -MD -MP -MF .deps/clmresidue.Tpo -c -o clmresidue.o clmresidue.c
# mv -f .deps/clmresidue.Tpo .deps/clmresidue.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clmclose.o -MD -MP -MF .deps/clmclose.Tpo -c -o clmclose.o clmclose.c
# mv -f .deps/clmclose.Tpo .deps/clmclose.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clmmate.o -MD -MP -MF .deps/clmmate.Tpo -c -o clmmate.o clmmate.c
# mv -f .deps/clmmate.Tpo .deps/clmmate.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clmmeet.o -MD -MP -MF .deps/clmmeet.Tpo -c -o clmmeet.o clmmeet.c
# mv -f .deps/clmmeet.Tpo .deps/clmmeet.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clmps.o -MD -MP -MF .deps/clmps.Tpo -c -o clmps.o clmps.c
# mv -f .deps/clmps.Tpo .deps/clmps.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clmdist.o -MD -MP -MF .deps/clmdist.Tpo -c -o clmdist.o clmdist.c
# mv -f .deps/clmdist.Tpo .deps/clmdist.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clmorder.o -MD -MP -MF .deps/clmorder.Tpo -c -o clmorder.o clmorder.c
# mv -f .deps/clmorder.Tpo .deps/clmorder.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clmoptics.o -MD -MP -MF .deps/clmoptics.Tpo -c -o clmoptics.o clmoptics.c
# mv -f .deps/clmoptics.Tpo .deps/clmoptics.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o clm clm.o clminfo2.o clminfo.o clmimac.o clmadjust.o clmresidue.o clmclose.o clmmate.o clmmeet.o clmps.o clmdist.o clmorder.o clmoptics.o report.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clmdag.o -MD -MP -MF .deps/clmdag.Tpo -c -o clmdag.o clmdag.c
# mv -f .deps/clmdag.Tpo .deps/clmdag.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o clmdag clmdag.o report.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT clmframe.o -MD -MP -MF .deps/clmframe.Tpo -c -o clmframe.o clmframe.c
# mv -f .deps/clmframe.Tpo .deps/clmframe.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o clmframe clmframe.o report.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# Making all in shmcl
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcl.o -MD -MP -MF .deps/mcl.Tpo -c -o mcl.o mcl.c
# mv -f .deps/mcl.Tpo .deps/mcl.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mcl mcl.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mclcm.o -MD -MP -MF .deps/mclcm.Tpo -c -o mclcm.o mclcm.c
# mv -f .deps/mclcm.Tpo .deps/mclcm.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mclcm mclcm.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# Making all in shmx
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcx.o -MD -MP -MF .deps/mcx.Tpo -c -o mcx.o mcx.c
# mv -f .deps/mcx.Tpo .deps/mcx.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxconvert.o -MD -MP -MF .deps/mcxconvert.Tpo -c -o mcxconvert.o mcxconvert.c
# mv -f .deps/mcxconvert.Tpo .deps/mcxconvert.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxquery.o -MD -MP -MF .deps/mcxquery.Tpo -c -o mcxquery.o mcxquery.c
# mv -f .deps/mcxquery.Tpo .deps/mcxquery.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxdiameter.o -MD -MP -MF .deps/mcxdiameter.Tpo -c -o mcxdiameter.o mcxdiameter.c
# mv -f .deps/mcxdiameter.Tpo .deps/mcxdiameter.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxclcf.o -MD -MP -MF .deps/mcxclcf.Tpo -c -o mcxclcf.o mcxclcf.c
# mv -f .deps/mcxclcf.Tpo .deps/mcxclcf.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxerdos.o -MD -MP -MF .deps/mcxerdos.Tpo -c -o mcxerdos.o mcxerdos.c
# mv -f .deps/mcxerdos.Tpo .deps/mcxerdos.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxcollect.o -MD -MP -MF .deps/mcxcollect.Tpo -c -o mcxcollect.o mcxcollect.c
# mv -f .deps/mcxcollect.Tpo .deps/mcxcollect.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxtab.o -MD -MP -MF .deps/mcxtab.Tpo -c -o mcxtab.o mcxtab.c
# mv -f .deps/mcxtab.Tpo .deps/mcxtab.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxfp.o -MD -MP -MF .deps/mcxfp.Tpo -c -o mcxfp.o mcxfp.c
# mv -f .deps/mcxfp.Tpo .deps/mcxfp.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxalter.o -MD -MP -MF .deps/mcxalter.Tpo -c -o mcxalter.o mcxalter.c
# mv -f .deps/mcxalter.Tpo .deps/mcxalter.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mcx mcx.o mcxconvert.o mcxquery.o mcxdiameter.o mcxclcf.o mcxerdos.o mcxcollect.o mcxtab.o mcxfp.o mcxalter.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxsubs.o -MD -MP -MF .deps/mcxsubs.Tpo -c -o mcxsubs.o mcxsubs.c
# mv -f .deps/mcxsubs.Tpo .deps/mcxsubs.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mcxsubs mcxsubs.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxmap.o -MD -MP -MF .deps/mcxmap.Tpo -c -o mcxmap.o mcxmap.c
# mv -f .deps/mcxmap.Tpo .deps/mcxmap.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mcxmap mcxmap.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxassemble.o -MD -MP -MF .deps/mcxassemble.Tpo -c -o mcxassemble.o mcxassemble.c
# mv -f .deps/mcxassemble.Tpo .deps/mcxassemble.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mcxassemble mcxassemble.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxarray.o -MD -MP -MF .deps/mcxarray.Tpo -c -o mcxarray.o mcxarray.c
# mv -f .deps/mcxarray.Tpo .deps/mcxarray.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mcxarray mcxarray.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxdump.o -MD -MP -MF .deps/mcxdump.Tpo -c -o mcxdump.o mcxdump.c
# mv -f .deps/mcxdump.Tpo .deps/mcxdump.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mcxdump mcxdump.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxload.o -MD -MP -MF .deps/mcxload.Tpo -c -o mcxload.o mcxload.c
# mv -f .deps/mcxload.Tpo .deps/mcxload.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mcxload mcxload.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxrand.o -MD -MP -MF .deps/mcxrand.Tpo -c -o mcxrand.o mcxrand.c
# mv -f .deps/mcxrand.Tpo .deps/mcxrand.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mcxrand mcxrand.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxtest2.o -MD -MP -MF .deps/mcxtest2.Tpo -c -o mcxtest2.o mcxtest2.c
# mv -f .deps/mcxtest2.Tpo .deps/mcxtest2.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mcxtest2 mcxtest2.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxtest.o -MD -MP -MF .deps/mcxtest.Tpo -c -o mcxtest.o mcxtest.c
# mv -f .deps/mcxtest.Tpo .deps/mcxtest.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mcxtest mcxtest.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxminusmeet.o -MD -MP -MF .deps/mcxminusmeet.Tpo -c -o mcxminusmeet.o mcxminusmeet.c
# mv -f .deps/mcxminusmeet.Tpo .deps/mcxminusmeet.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mcxminusmeet mcxminusmeet.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxmm.o -MD -MP -MF .deps/mcxmm.Tpo -c -o mcxmm.o mcxmm.c
# mv -f .deps/mcxmm.Tpo .deps/mcxmm.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mcxmm mcxmm.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxmetric.o -MD -MP -MF .deps/mcxmetric.Tpo -c -o mcxmetric.o mcxmetric.c
# mv -f .deps/mcxmetric.Tpo .deps/mcxmetric.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mcxmetric mcxmetric.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# Making all in shmcx
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxi.o -MD -MP -MF .deps/mcxi.Tpo -c -o mcxi.o mcxi.c
# mv -f .deps/mcxi.Tpo .deps/mcxi.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT stack.o -MD -MP -MF .deps/stack.Tpo -c -o stack.o stack.c
# mv -f .deps/stack.Tpo .deps/stack.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT glob.o -MD -MP -MF .deps/glob.Tpo -c -o glob.o glob.c
# mv -f .deps/glob.Tpo .deps/glob.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT util.o -MD -MP -MF .deps/util.Tpo -c -o util.o util.c
# mv -f .deps/util.Tpo .deps/util.Po
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT ops.o -MD -MP -MF .deps/ops.Tpo -c -o ops.o ops.c
# mv -f .deps/ops.Tpo .deps/ops.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mcxi mcxi.o stack.o glob.o util.o ops.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# Making all in shmcxquery
# gcc -DHAVE_CONFIG_H -I. -I../.. -I../../src -I../..    -g -O2 -D_THREAD_SAFE  -MT mcxquery.o -MD -MP -MF .deps/mcxquery.Tpo -c -o mcxquery.o mcxquery.c
# mv -f .deps/mcxquery.Tpo .deps/mcxquery.Po
# gcc  -g -O2 -D_THREAD_SAFE  -lm  -o mcxquery mcxquery.o ../mcl/libmcl.a ../clew/libclew.a  ../gryphon/libgryphon.a ../impala/libimpala.a ../../util/libutil.a -lm
# Making all in alien
# make[4]: Nothing to be done for `all-am'.
# Making all in include
# Making all in .
# make[3]: Nothing to be done for `all-am'.
# Making all in scripts
# make[2]: Nothing to be done for `all'.
# Making all in testing
# Making all in .
# make[3]: Nothing to be done for `all-am'.
# Making all in stream
# make[3]: Nothing to be done for `all'.
# Making all in blast
# make[3]: Nothing to be done for `all'.
# Making all in setops
# make[3]: Nothing to be done for `all'.
# Making install in .
# make[2]: Nothing to be done for `install-exec-am'.
# make[2]: Nothing to be done for `install-data-am'.
# Making install in util
# make[2]: Nothing to be done for `install-exec-am'.
# make[2]: Nothing to be done for `install-data-am'.
# Making install in img
# make[2]: Nothing to be done for `install-exec-am'.
# test -z "/usr/local/share/doc/mcl/examples" || ../autofoo/install-sh -c -d "/usr/local/share/doc/mcl/examples"
#  /usr/bin/install -c -m 644 fa_1024.png fa_400.png fa_600.png fa_large.png fa.ps falkner-bidi.ps falkner.ps small.ps small.png '/usr/local/share/doc/mcl/examples'
# Making install in graphs
# make[2]: Nothing to be done for `install-exec-am'.
# test -z "/usr/local/share/doc/mcl/examples" || ../autofoo/install-sh -c -d "/usr/local/share/doc/mcl/examples"
#  /usr/bin/install -c -m 644 falkner.mci falkner2.mci falkner.coords make-falkner.pl proteins.mci matula.mci lattice.mci honey.mci seven.mci infinity.mci friends small.mci small.map small.tab fznyy.tab fznyy.mci small64.mci petersen.mci tiny-min.mci tiny-nil.mci tiny-nilnine.mci tiny-ninenil.mci tiny-one.mci tiny-zero.mci data.raw data.hdr data.tab data.abc.raw data.abc.hdr data.abc.map T Tx Ty Txy '/usr/local/share/doc/mcl/examples'
# Making install in doc
# make[2]: Nothing to be done for `install-exec-am'.
# test -z "/usr/local/share/doc/mcl" || ../autofoo/install-sh -c -d "/usr/local/share/doc/mcl"
#  /usr/bin/install -c -m 644 mcl.html mcl.ps mcl.txt mclcm.html mclcm.ps mclcm.txt mclfaq.html mclfaq.ps mclfaq.txt mclfamily.html mclfamily.ps mcx.html mcx.ps mcxi.html mcxi.ps clm.html clm.ps mcxconvert.html mcxconvert.ps mcxarray.html mcxarray.ps mcxdump.html mcxdump.ps mcxdiameter.html mcxdiameter.ps mcxerdos.html mcxerdos.ps mcxalter.html mcxalter.ps mcxclcf.html mcxclcf.ps mcxctty.html mcxctty.ps mcxrand.html mcxrand.ps mcxload.html mcxload.ps mcxsubs.html mcxsubs.ps mcxmap.html '/usr/local/share/doc/mcl'
#  /usr/bin/install -c -m 644 mcxmap.ps mcxquery.html mcxquery.ps mcxassemble.html mcxassemble.ps mclpipeline.html mclpipeline.ps index.html mclindex.ps clmimac.html clmimac.ps clmoptics.html clmoptics.ps clmclose.html clmclose.ps clmresidue.html clmresidue.ps clmdist.html clmdist.ps clmvol.html clmvol.ps clminfo.html clminfo.ps clminfo2.html clminfo2.ps clmmate.html clmmate.ps clmmeet.html clmmeet.ps clmformat.html clmformat.ps clmorder.html clmorder.ps minimcl mcxio.html mcxio.ps clmprotocols.html clmprotocols.ps clmprotocols2.html clmprotocols2.ps '/usr/local/share/doc/mcl'
#  /usr/bin/install -c -m 644 tingea.log.html tingea.log.ps mclmcl.txt '/usr/local/share/doc/mcl'
# test -z "/usr/local/share/man/man1" || ../autofoo/install-sh -c -d "/usr/local/share/man/man1"
#  /usr/bin/install -c -m 644 mcl.1 mclcm.1 clm.1 mcx.1 mcxi.1 clmresidue.1 clmclose.1 clmoptics.1 clmimac.1 clmmate.1 clmmeet.1 clmformat.1 clmvol.1 clmdist.1 clminfo2.1 clminfo.1 clmorder.1 mcxconvert.1 mcxassemble.1 mcxmap.1 mcxsubs.1 mcxload.1 mcxdump.1 mcxarray.1 mcxrand.1 mcxalter.1 mcxerdos.1 mcxdiameter.1 mcxctty.1 mcxclcf.1 mcxquery.1 mclpipeline.1 '/usr/local/share/man/man1'
# test -z "/usr/local/share/man/man5" || ../autofoo/install-sh -c -d "/usr/local/share/man/man5"
#  /usr/bin/install -c -m 644 mcxio.5 clmprotocols2.5 clmprotocols.5 '/usr/local/share/man/man5'
# test -z "/usr/local/share/man/man7" || ../autofoo/install-sh -c -d "/usr/local/share/man/man7"
#  /usr/bin/install -c -m 644 mclindex.7 mclfamily.7 mclfaq.7 tingea.log.7 '/usr/local/share/man/man7'
# Making install in src
# Making install in .
# make[3]: Nothing to be done for `install-exec-am'.
# make[3]: Nothing to be done for `install-data-am'.
# Making install in clew
# make[3]: Nothing to be done for `install-exec-am'.
# make[3]: Nothing to be done for `install-data-am'.
# Making install in mcl
# make[3]: Nothing to be done for `install-exec-am'.
# make[3]: Nothing to be done for `install-data-am'.
# Making install in gryphon
# make[3]: Nothing to be done for `install-exec-am'.
# make[3]: Nothing to be done for `install-data-am'.
# Making install in impala
# make[3]: Nothing to be done for `install-exec-am'.
# make[3]: Nothing to be done for `install-data-am'.
# Making install in shcl
# test -z "/usr/local/bin" || ../../autofoo/install-sh -c -d "/usr/local/bin"
#   /usr/bin/install -c clmformat clm '/usr/local/bin'
# test -z "/usr/local/bin" || ../../autofoo/install-sh -c -d "/usr/local/bin"
#  /usr/bin/install -c mclpipeline '/usr/local/bin'
# make[3]: Nothing to be done for `install-data-am'.
# Making install in shmcl
# test -z "/usr/local/bin" || ../../autofoo/install-sh -c -d "/usr/local/bin"
#   /usr/bin/install -c mcl mclcm '/usr/local/bin'
# make[3]: Nothing to be done for `install-data-am'.
# Making install in shmx
# test -z "/usr/local/bin" || ../../autofoo/install-sh -c -d "/usr/local/bin"
#   /usr/bin/install -c mcx mcxsubs mcxmap mcxassemble mcxarray mcxdump mcxload mcxrand '/usr/local/bin'
# make[3]: Nothing to be done for `install-data-am'.
# Making install in shmcx
# test -z "/usr/local/bin" || ../../autofoo/install-sh -c -d "/usr/local/bin"
#   /usr/bin/install -c mcxi '/usr/local/bin'
# make[3]: Nothing to be done for `install-data-am'.
# Making install in shmcxquery
# make[3]: Nothing to be done for `install-exec-am'.
# make[3]: Nothing to be done for `install-data-am'.
# Making install in alien
# make[4]: Nothing to be done for `install-exec-am'.
# make[4]: Nothing to be done for `install-data-am'.
# Making install in include
# Making install in .
# make[3]: Nothing to be done for `install-exec-am'.
# make[3]: Nothing to be done for `install-data-am'.
# Making install in scripts
# test -z "/usr/local/bin" || ../autofoo/install-sh -c -d "/usr/local/bin"
#  /usr/bin/install -c clxdo '/usr/local/bin'
# make[2]: Nothing to be done for `install-data-am'.
# Making install in testing
# Making install in .
# make[3]: Nothing to be done for `install-exec-am'.
# make[3]: Nothing to be done for `install-data-am'.
# Making install in stream
# make[3]: Nothing to be done for `install-exec-am'.
# make[3]: Nothing to be done for `install-data-am'.
# Making install in blast
# make[3]: Nothing to be done for `install-exec-am'.
# make[3]: Nothing to be done for `install-data-am'.
# Making install in setops
# make[3]: Nothing to be done for `install-exec-am'.
# make[3]: Nothing to be done for `install-data-am'.
# Making clean in testing
# Making clean in setops
# make[2]: Nothing to be done for `clean'.
# Making clean in blast
# make[2]: Nothing to be done for `clean'.
# Making clean in stream
# make[2]: Nothing to be done for `clean'.
# Making clean in .
# make[2]: Nothing to be done for `clean-am'.
# Making clean in scripts
# make[1]: Nothing to be done for `clean'.
# Making clean in include
# Making clean in .
# make[2]: Nothing to be done for `clean-am'.
# Making clean in src
# Making clean in alien
# Making clean in .
# make[3]: Nothing to be done for `clean-am'.
# Making clean in shmcxquery
# test -z "mcxquery" || rm -f mcxquery
# rm -f *.o
# Making clean in shmcx
# test -z "mcxi" || rm -f mcxi
# rm -f *.o
# Making clean in shmx
# test -z "mcx mcxsubs mcxmap mcxassemble mcxarray mcxdump mcxload mcxrand" || rm -f mcx mcxsubs mcxmap mcxassemble mcxarray mcxdump mcxload mcxrand
# test -z "mcxtest2 mcxtest mcxminusmeet mcxmm mcxmetric" || rm -f mcxtest2 mcxtest mcxminusmeet mcxmm mcxmetric
# rm -f *.o
# Making clean in shmcl
# test -z "mcl mclcm" || rm -f mcl mclcm
# rm -f *.o
# Making clean in shcl
# test -z "clmformat clm" || rm -f clmformat clm
# test -z "clmdag clmframe" || rm -f clmdag clmframe
# rm -f *.o
# Making clean in impala
# test -z "libimpala.a" || rm -f libimpala.a
# rm -f *.o
# Making clean in gryphon
# test -z "libgryphon.a" || rm -f libgryphon.a
# rm -f *.o
# Making clean in mcl
# test -z "libmcl.a" || rm -f libmcl.a
# rm -f *.o
# Making clean in clew
# test -z "libclew.a" || rm -f libclew.a
# rm -f *.o
# Making clean in .
# make[2]: Nothing to be done for `clean-am'.
# Making clean in doc
# make[1]: Nothing to be done for `clean'.
# Making clean in graphs
# make[1]: Nothing to be done for `clean'.
# Making clean in img
# make[1]: Nothing to be done for `clean'.
# Making clean in util
# test -z "libutil.a" || rm -f libutil.a
# rm -f *.o
# Making clean in .
# make[1]: Nothing to be done for `clean-am'.
# Making distclean in testing
# Making distclean in setops
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f Makefile
# Making distclean in blast
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f Makefile
# Making distclean in stream
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f Makefile
# Making distclean in .
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f TAGS ID GTAGS GRTAGS GSYMS GPATH tags
# rm -f Makefile
# Making distclean in scripts
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f Makefile
# Making distclean in include
# Making distclean in .
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f TAGS ID GTAGS GRTAGS GSYMS GPATH tags
# rm -f Makefile
# Making distclean in src
# Making distclean in alien
# Making distclean in oxygen
# Making distclean in src
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f Makefile
# Making distclean in doc
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f Makefile
# Making distclean in .
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f TAGS ID GTAGS GRTAGS GSYMS GPATH tags
# rm -f Makefile
# Making distclean in .
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f TAGS ID GTAGS GRTAGS GSYMS GPATH tags
# rm -f Makefile
# Making distclean in shmcxquery
# test -z "mcxquery" || rm -f mcxquery
# rm -f *.o
# rm -f *.tab.c
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f TAGS ID GTAGS GRTAGS GSYMS GPATH tags
# rm -rf ./.deps
# rm -f Makefile
# Making distclean in shmcx
# test -z "mcxi" || rm -f mcxi
# rm -f *.o
# rm -f *.tab.c
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f TAGS ID GTAGS GRTAGS GSYMS GPATH tags
# rm -rf ./.deps
# rm -f Makefile
# Making distclean in shmx
# test -z "mcx mcxsubs mcxmap mcxassemble mcxarray mcxdump mcxload mcxrand" || rm -f mcx mcxsubs mcxmap mcxassemble mcxarray mcxdump mcxload mcxrand
# test -z "mcxtest2 mcxtest mcxminusmeet mcxmm mcxmetric" || rm -f mcxtest2 mcxtest mcxminusmeet mcxmm mcxmetric
# rm -f *.o
# rm -f *.tab.c
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f TAGS ID GTAGS GRTAGS GSYMS GPATH tags
# rm -rf ./.deps
# rm -f Makefile
# Making distclean in shmcl
# test -z "mcl mclcm" || rm -f mcl mclcm
# rm -f *.o
# rm -f *.tab.c
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f TAGS ID GTAGS GRTAGS GSYMS GPATH tags
# rm -rf ./.deps
# rm -f Makefile
# Making distclean in shcl
# test -z "clmformat clm" || rm -f clmformat clm
# test -z "clmdag clmframe" || rm -f clmdag clmframe
# rm -f *.o
# rm -f *.tab.c
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f TAGS ID GTAGS GRTAGS GSYMS GPATH tags
# rm -rf ./.deps
# rm -f Makefile
# Making distclean in impala
# test -z "libimpala.a" || rm -f libimpala.a
# rm -f *.o
# rm -f *.tab.c
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f TAGS ID GTAGS GRTAGS GSYMS GPATH tags
# rm -rf ./.deps
# rm -f Makefile
# Making distclean in gryphon
# test -z "libgryphon.a" || rm -f libgryphon.a
# rm -f *.o
# rm -f *.tab.c
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f TAGS ID GTAGS GRTAGS GSYMS GPATH tags
# rm -rf ./.deps
# rm -f Makefile
# Making distclean in mcl
# test -z "libmcl.a" || rm -f libmcl.a
# rm -f *.o
# rm -f *.tab.c
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f TAGS ID GTAGS GRTAGS GSYMS GPATH tags
# rm -rf ./.deps
# rm -f Makefile
# Making distclean in clew
# test -z "libclew.a" || rm -f libclew.a
# rm -f *.o
# rm -f *.tab.c
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f TAGS ID GTAGS GRTAGS GSYMS GPATH tags
# rm -rf ./.deps
# rm -f Makefile
# Making distclean in .
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f TAGS ID GTAGS GRTAGS GSYMS GPATH tags
# rm -f Makefile
# Making distclean in doc
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f Makefile
# Making distclean in graphs
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f Makefile
# Making distclean in img
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f Makefile
# Making distclean in util
# test -z "libutil.a" || rm -f libutil.a
# rm -f *.o
# rm -f *.tab.c
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f TAGS ID GTAGS GRTAGS GSYMS GPATH tags
# rm -rf ./.deps
# rm -f Makefile
# Making distclean in .
# test -z "" || rm -f
# test . = "." || test -z "" || rm -f
# rm -f config.h stamp-h1
# rm -f TAGS ID GTAGS GRTAGS GSYMS GPATH tags
# rm -f config.status config.cache config.log configure.lineno config.status.lineno
# rm -f Makefile
# 0

# %%
# set the inflation parameter of the Markov Clustering Algorithm(MCL)
inflation = 2

# %%
# This function prepares the inputs to the markov clustering algorithm (MCL)
# 1. it creates a pickle file for the output clusters with interaction information
# 2. it also returns a modified baseline model (without introducing new nodes)
    
from markovCluster import runMarkovCluster
res, new_base_model = runMarkovCluster(out_dir,exttt,model_dict,inflation)
# Out:
# INFO:root:Running the following command through MCL algorithm:
# mcl output/abc_model --abc -I 2 -o output/markov_cluster
#
# [mcl] new tab created
# [mcl] pid 73975
#  ite -----------------  chaos  time hom(avg,lo,hi) m-ie m-ex i-ex fmv
#   1  .................  11.98  0.00 1.01/0.05/1.70 4.57 4.57 4.57  71
#   2  .................  19.01  0.00 0.70/0.30/1.05 3.64 2.70 12.35  94
#   3  .................  11.78  0.00 0.73/0.32/1.14 1.71 0.44 5.46  94
#   4  .................   6.19  0.00 0.87/0.39/1.21 3.05 0.36 1.97  94
#   5  .................   1.98  0.00 0.92/0.48/1.35 2.51 0.38 0.76  77
#   6  .................   1.07  0.00 0.97/0.53/1.02 1.45 0.59 0.45  29
#   7  .................   0.57  0.00 0.98/0.60/1.00 1.15 0.68 0.31   9
#   8  .................   0.36  0.00 0.99/0.75/1.03 1.00 0.89 0.27   0
#   9  .................   0.16  0.00 1.00/0.88/1.16 0.99 0.97 0.27   0
#  10  .................   0.31  0.00 1.00/0.81/1.00 0.99 0.98 0.27   0
#  11  .................   0.24  0.00 0.99/0.64/1.00 0.99 0.94 0.25   0
#  12  .................   0.11  0.00 1.00/0.89/1.00 0.99 0.98 0.25   0
#  13  .................   0.01  0.00 1.00/0.99/1.00 0.99 0.99 0.25   0
#  14  .................   0.00  0.00 1.00/1.00/1.00 0.99 0.98 0.25   0
# [mcl] jury pruning marks: <100,99,99>, out of 100
# [mcl] jury pruning synopsis: <99.6 or perfect> (cf -scheme, -do log)
# [mcl] output is in output/markov_cluster
# [mcl] 26 clusters found
# [mcl] output is in output/markov_cluster
#
# Please cite:
#     Stijn van Dongen, Graph Clustering by Flow Simulation.  PhD thesis,
#     University of Utrecht, May 2000.
#        (  http://www.library.uu.nl/digiarchief/dip/diss/1895620/full.pdf
#        or  http://micans.org/mcl/lit/svdthesis.pdf.gz)
# OR
#     Stijn van Dongen, A cluster algorithm for graphs. Technical
#     Report INS-R0010, National Research Institute for Mathematics
#     and Computer Science in the Netherlands, Amsterdam, May 2000.
#        (  http://www.cwi.nl/ftp/CWIreports/INS/INS-R0010.ps.Z
#        or  http://micans.org/mcl/lit/INS-R0010.ps.Z)

# %%
# Take a look at these clusters found by MCL
with open(out_dir+'markov_cluster','r') as f:
    for line in f:
        print(line)
# Out:
# AKT_OFF	AKT	CHK1_ext	CTLA4_ext	IFNgamma_ext	MEK1_ext	PD1_ext	PDK1	SHIP1_ext	TBK1_ext	TGFBETA	TIL_ext	CD4_ext	Bcl2l11_ext	CTRL_ext	FOXO1	FoxO3_ext	Foxo3a_ext	MAGI1_ext
#
# PIP3	PTEN	TCR	HSC_ext	PI3K_HIGH	PI3K_LOW	NEDD4_ext	TCR_HIGH	PIP3_HIGH	PIP3_LOW	P53_ext
#
# CD25	FOXP3	Ctla4_ext	SMAD3	Gpr83_ext	IL2
#
# MTOR	MTOR_DD	MTORC2_D	MTOR_D	Pak1_ext
#
# CD122	IL2R	CD132	IL2_EX	JAK3
#
# MTORC1_D	MTORC1_OFF	MTORC1	RHEB	TSC
#
# JUN	MKK7	JNK	TAK1
#
# PDL1_ext	CD8_ext	Treg_ext	gp120_ext
#
# MEK2	IQGAP1_ext	RAF	RAS
#
# BAM32_ext	PAK1_ext	BIM_ext	siPAK1_ext
#
# MTORC2	NFKAPPAB	CD28
#
# FOS_DD	FOS	FOS_D
#
# CA	NFAT	NFAT_OFF
#
# Itk_ext	Myc_ext	Th17_ext
#
# CK2_ext	CDC37_ext
#
# PI3K	SHIP_ext
#
# STAT5	STAT5_D
#
# Bcl2_ext	CD3_ext
#
# P38_ext	CD5_ext
#
# SP_ext	CD69_ext
#
# ERK	S5B_ext
#
# FASL_ext	FAS_ext
#
# IL17A_ext	HIF1alpha_ext
#
# S6K1	PS6
#
# PKCTHETA	TCR_LOW
#
# AP1

# %%
# show clusters with interaction information added, it's one output of runMarkovCluster()
res
# Out:
# [[1,
#   ['AKT', 'FoxO3_ext', '-'],
#   ['MTORC2', 'AKT', '+'],
#   ['MEK1_ext', 'PTEN', '+'],
#   ['TBK1_ext', 'CD4_ext', '+'],
#   ['AKT', 'FOXO1', '-'],
#   ['AKT', 'MEK1_ext', '-'],
#   ['SHIP1_ext', 'AKT', '-'],
#   ['PIP3', 'AKT', '+'],
#   ['CK2_ext', 'AKT', '+'],
#   ['MTOR', 'AKT', '+'],
#   ['AKT', 'TBK1_ext', '+'],
#   ['Itk_ext', 'CD4_ext', '+'],
#   ['TCR', 'AKT', '-'],
#   ['FOXO1', 'Foxo3a_ext', '-'],
#   ['CHK1_ext', 'AKT', '+'],
#   ['Itk_ext', 'CD4_ext', '-'],
#   ['PDK1', 'AKT', '+'],
#   ['CK2_ext', 'CD4_ext', '+'],
#   ['AKT', 'MTORC2', '-'],
#   ['CTLA4_ext', 'AKT', '-'],
#   ['TIL_ext', 'AKT', '-'],
#   ['MEK1_ext', 'AKT', '-'],
#   ['PI3K', 'AKT', '+'],
#   ['MTOR', 'TBK1_ext', '+'],
#   ['PI3K', 'AKT', '-'],
#   ['TGFBETA', 'AKT', '+'],
#   ['TBK1_ext', 'FOXO1', '+'],
#   ['TCR', 'CD4_ext', '-'],
#   ['TCR', 'MEK1_ext', '+'],
#   ['FOXO1', 'PTEN', '+'],
#   ['IFNgamma_ext', 'AKT', '+'],
#   ['TBK1_ext', 'AKT', '-'],
#   ['PTEN', 'AKT', '+'],
#   ['AKT', 'CTRL_ext', '-'],
#   ['AKT', 'CD4_ext', '-'],
#   ['AKT', 'Itk_ext', '-'],
#   ['PTEN', 'AKT', '-'],
#   ['PD1_ext', 'AKT', '-'],
#   ['AKT', 'MAGI1_ext', '-'],
#   ['Bcl2l11_ext', 'CD4_ext', '+'],
#   ['TBK1_ext', 'CD4_ext', '-'],
#   ['CD4_ext', 'IL17A_ext', '-'],
#   ['TBK1_ext', 'AKT', '+']],
#  [2,
#   ['PTEN', 'PIP3', '-'],
#   ['PI3K', 'PIP3', '+'],
#   ['TCR', 'CK2_ext', '+'],
#   ['TCR', 'MTORC2', '+'],
#   ['PTEN', 'HSC_ext', '+'],
#   ['NEDD4_ext', 'PTEN', '-'],
#   ['CK2_ext', 'PTEN', '-'],
#   ['TCR', 'NEDD4_ext', '+'],
#   ['PTEN', 'CD8_ext', '+'],
#   ['MEK2', 'PTEN', '+'],
#   ['TCR', 'PIP3', '+'],
#   ['TCR', 'Itk_ext', '+'],
#   ['PI3K', 'PTEN', '-'],
#   ['TCR', 'CD25', '+'],
#   ['PTEN', 'Itk_ext', '-'],
#   ['TCR', 'PTEN', '-'],
#   ['RAS', 'PTEN', '-'],
#   ['PI3K', 'PTEN', '+'],
#   ['P53_ext', 'PTEN', '-']],
#  [3,
#   ['FOXP3', 'Gpr83_ext', '+'],
#   ['CD25', 'MTORC2', '+'],
#   ['IL2', 'MTORC2', '+'],
#   ['FOXP3', 'Itk_ext', '+'],
#   ['FOXP3', 'Ctla4_ext', '+'],
#   ['IL2', 'Itk_ext', '+']],
#  [4, ['MTOR', 'Pak1_ext', '-'], ['MTOR', 'PAK1_ext', '+']],
#  [5,
#   ['PDL1_ext', 'gp120_ext', '+'],
#   ['PDL1_ext', 'CD8_ext', '-'],
#   ['PDL1_ext', 'Treg_ext', '-']],
#  [6, ['IQGAP1_ext', 'MEK2', '-']],
#  [7,
#   ['PI3K', 'PAK1_ext', '-'],
#   ['BIM_ext', 'PAK1_ext', '+'],
#   ['siPAK1_ext', 'PAK1_ext', '-'],
#   ['ERK', 'PAK1_ext', '+'],
#   ['BAM32_ext', 'PAK1_ext', '+']],
#  [8, ['MTORC2', 'MTORC2', '+'], ['CD28', 'MTORC2', '+']],
#  [9, ['Itk_ext', 'Myc_ext', '-'], ['Itk_ext', 'Th17_ext', '+']],
#  [10,
#   ['CD5_ext', 'CK2_ext', '+'],
#   ['ERK', 'CK2_ext', '+'],
#   ['CK2_ext', 'CDC37_ext', '+']],
#  [11, ['SHIP_ext', 'PI3K', '+']],
#  [12, ['Bcl2_ext', 'CD3_ext', '+']],
#  [13, ['CD5_ext', 'P38_ext', '+'], ['P38_ext', 'CD5_ext', '+']],
#  [14, ['SP_ext', 'CD69_ext', '+']],
#  [15, ['ERK', 'S5B_ext', '+']],
#  [16, ['FASL_ext', 'FAS_ext', '+']],
#  [17, ['HIF1alpha_ext', 'IL17A_ext', '-']]]

# %%
# show the modified baseline model (without introducing new nodes), it's another output of runMarkovCluster()
new_base_model
# Out:
# {'AKT': {'AKT_OFF', 'MTORC2', 'PDK1'},
#  'AKT_OFF': set(),
#  'AP1': {'FOS_DD', 'JUN'},
#  'CA': {'TCR'},
#  'CD122': set(),
#  'CD132': set(),
#  'CD25': {'AP1', 'FOXP3', 'NFAT', 'NFKAPPAB', 'STAT5'},
#  'CD28': set(),
#  'ERK': {'MEK2'},
#  'FOS': {'ERK'},
#  'FOS_D': {'FOS'},
#  'FOS_DD': {'FOS_D'},
#  'FOS_DDD': set(),
#  'FOXP3': {'MTOR_DD', 'NFAT', 'SMAD3', 'STAT5'},
#  'IL2': {'AP1', 'FOXP3', 'IL2', 'NFAT', 'NFKAPPAB'},
#  'IL2_EX': {'IL2', 'IL2_EX'},
#  'IL2R': {'CD122', 'CD132', 'CD25'},
#  'JAK3': {'IL2R', 'IL2_EX'},
#  'JNK': {'MKK7'},
#  'JUN': {'JNK'},
#  'MEK2': {'RAF'},
#  'MKK7': {'TAK1'},
#  'MTOR': {'MTORC1_D', 'MTORC2_D'},
#  'MTOR_D': {'MTOR'},
#  'MTOR_DD': {'MTOR_D'},
#  'MTOR_DDD': set(),
#  'MTOR_DDDD': set(),
#  'MTORC1': {'MTORC1_OFF', 'RHEB'},
#  'MTORC1_D': {'MTORC1'},
#  'MTORC1_OFF': set(),
#  'MTORC2': {'PI3K_HIGH', 'PI3K_LOW', 'S6K1'},
#  'MTORC2_D': {'MTORC2'},
#  'MTORC2_DD': set(),
#  'NFAT': {'CA', 'NFAT_OFF'},
#  'NFAT_OFF': set(),
#  'NFKAPPAB': {'AKT', 'PKCTHETA'},
#  'PDK1': {'PIP3'},
#  'PI3K': {'PI3K_HIGH', 'PI3K_LOW'},
#  'PI3K_HIGH': {'CD28', 'IL2R', 'IL2_EX', 'PI3K_HIGH', 'TCR_HIGH'},
#  'PI3K_LOW': {'CD28', 'IL2R', 'IL2_EX', 'PI3K_LOW', 'TCR_LOW'},
#  'PIP3': {'PIP3_HIGH', 'PIP3_LOW'},
#  'PIP3_HIGH': {'PI3K_HIGH', 'PTEN'},
#  'PIP3_LOW': {'PI3K_LOW', 'PTEN'},
#  'PKCTHETA': {'CD28', 'MTORC2', 'TCR_HIGH', 'TCR_LOW'},
#  'PS6': {'S6K1'},
#  'PTEN': {'FOXP3', 'PTEN', 'TCR_HIGH'},
#  'RAF': {'RAS'},
#  'RAS': {'CD28', 'IL2R', 'IL2_EX', 'RAS', 'TCR'},
#  'RHEB': {'TSC'},
#  'S6K1': {'MTORC1'},
#  'SMAD3': {'TGFBETA'},
#  'STAT5': {'JAK3'},
#  'STAT5_D': {'STAT5'},
#  'STAT5_DD': set(),
#  'STAT5_DDD': set(),
#  'TAK1': {'PKCTHETA'},
#  'TCR': {'TCR_HIGH', 'TCR_LOW'},
#  'TCR_HIGH': set(),
#  'TCR_LOW': set(),
#  'TGFBETA': set(),
#  'TSC': {'AKT'},
#  'FOXO1': set()}

# %%
return_path_TH = 5

# %%
# This function records indices of clusters to be merged based on the existence of return paths
# It generates the grouped_ext_Merged pickle file that contains the merged clusters

from runAccordion import merge_clusters
merge_clusters(regulators, out_dir, return_path_TH)
# Out:
# INFO:root:Merge clusters NO.1 and NO.2

# %% [markdown]
# # 4 Extend Model to Create New Spreadsheet

# %%
# prepare the merged clusters for spreadsheet modification
p_file = open(out_dir+'grouped_ext_Merged','rb')
merged_res = pickle.load(p_file)

# %%
# regulate names
# output extended models are stored in 'examples/output/''
original_model = in_dir + model_file
extended_name = out_dir + model_file.split('.')[0] + '_Extension_'

# %%
# choose candidate extension, either from the unmerged clusters or merged clusters
candidate = merged_res
#candidate = res

# %%
from runAccordion import extend_model

for i in range(len(candidate)):
    extend_model(original_model,candidate[i],extended_name+str(i+1)+'.xlsx')
